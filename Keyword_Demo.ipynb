# %% [markdown]
# <a href="https://colab.research.google.com/github/ucalyptus/dirac-dev/blob/master/Keyword_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-522c1d9d-e324-4b45-a480-6ea49653352b" name="files[]" multiple disabled />
#      <output id="result-522c1d9d-e324-4b45-a480-6ea49653352b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving report4.txt to report4.txt
# {'report4.txt': b'for the Year Ended December 31, 2013\r\n FINANCIAL STATEMENTS O\r\nF  adidas AG\r\n    \r\n   CONTENTS\r\n   \r\n3 \r\nInformation on the combined Management Report\r\n  \r\n4 \r\nBalance Sheet\r\n  \r\n5 Income \r\nStatement\r\n  \r\n6 \r\nNotes\r\n  \r\n32 \r\nStatements of Changes in Fixed Assets\r\n  \r\n34 \r\nSupervisory Board and Executive Board\r\n  \r\n38 \r\nList of Shareholdings \r\n  \r\n46 \r\nAuditors\xe2\x84\xa2 Report\r\n  \r\n48 \r\nResponsi\r\nbility Statement\r\n  \r\n49 \r\nSupervisory Board Report\r\n  \r\n \r\n \r\n \r\n \r\n \r\n \r\n \r\n Combined Management Report\r\n  The Management Report of adidas AG has been combined with the Management Report of \r\nthe adidas Group in accordance with \xc2\xa7 315 section\r\n 3 together with \xc2\xa7 298 section 3 of the \r\nGerman Commercial Code (Handelsgesetzbuch \r\n\xc5\x92 HGB) and is published in the 201\r\n3 \r\nAnnual \r\nReport of the adidas Group.\r\n The Financial Statements and the combined Management Report for adidas AG and the \r\n\r\nadidas Group for the 201\r\n3 \r\nfinancial year are\r\n filed with and published in the Federal Gazette.\r\n The Financial Statements of adidas AG as well as the Annual Report for the 201\r\n3 \r\nfinancial \r\nyear are also available for download on the Internet at \r\n http://www.adidas\r\n-group.com/en/investors/financial\r\n-reports/\r\n Annual financial statements of adidas AG\r\n   Balance Sheet\r\n EUR thousand\r\n      Dec. 31, 2013\r\n Dec. 31, 2012\r\n ASSETS\r\n        FIXED ASSETS\r\n (1)\r\n   Intangible assets\r\n (2)\r\n 147,804\r\n 151,894\r\n Tangible assets\r\n (2)\r\n 303,794\r\n 264,398\r\n Financial assets\r\n (3)\r\n 3,475,917\r\n 3,480,206\r\n   3,927,515\r\n 3,896,498\r\n CURRENT ASSETS\r\n    Inventories\r\n (4)\r\n 29,339\r\n 32,541\r\n Receivables and other assets\r\n (5)\r\n 1,928,325\r\n 1,976,406\r\n Cash and cash equivalents\r\n (6)\r\n 735,598\r\n 1,048,306\r\n   2,693,262\r\n 3,057,253\r\n PREPAID EXPENSES\r\n (7)\r\n 73,652\r\n 76,041\r\n   6,694,429\r\n 7,029,792\r\n     EQUITY AND LIABILITIES\r\n        EQUITY\r\n    Subscribed capital\r\n (8)\r\n 209,216\r\n 209,216\r\n Capital reserves\r\n (8)\r\n 1,200,966\r\n 1,200,966\r\n Revenue reserves\r\n  655,128\r\n 655,128\r\n Retained earnings\r\n (9)\r\n 424,076\r\n 606,495\r\n   2,489,386\r\n 2,671,805\r\n UNTAXED RESERVE\r\n (10)\r\n 4,719\r\n 5,041\r\n     PROVISIONS/ACCRUALS\r\n (11)\r\n 393,401\r\n 361,098\r\n     LIABILITIES\r\n (12)\r\n 3,806.719\r\n 3,991,772\r\n     DEFERRED INCOME\r\n  204 76   6,694,429\r\n 7,029,792\r\n  Annual financial statements of adidas AG\r\n  Income Statement\r\n EUR thousand\r\n      2013 2012     Sales\r\n (14)\r\n 1,952,467\r\n 2,004,541\r\n Change in inventory\r\n  1,045\r\n -54 Total output\r\n  1,953,512\r\n 2,004,487\r\n     Other operating income\r\n (15)\r\n 1,164,880\r\n 1,269,892\r\n Cost of materials\r\n (16)\r\n -532,143\r\n -573,655\r\n Personnel expenses\r\n (17)\r\n -357,026\r\n -343,419\r\n Amortization and write\r\n-downs of intangible fixed assets and \r\ndepreciation and write\r\n-downs of tangible fixed\r\n assets\r\n    (19)\r\n -80,583\r\n -71,431\r\n Other operating expenses\r\n (19)\r\n -1,980,611\r\n -2,055,398\r\n Income from operations\r\n  168,029\r\n 230,476\r\n     Income from investments in related companies\r\n (20)\r\n 102,486\r\n 86,212\r\n Profit received under a profit and loss transfer \r\nagreement\r\n    (21)\r\n 5,832\r\n 335,841\r\n Write\r\n-downs of long\r\n-term financial assets\r\n (22)\r\n -2,841\r\n 0 Interest result\r\n (23)\r\n -62,281\r\n -72,135\r\n Income from ordinary activities\r\n  211,225\r\n 580,394\r\n     Taxes on income\r\n (24)\r\n -111,138\r\n -76,149\r\n Other taxes\r\n  -64 -740 NET \r\nINCOME\r\n  100,023\r\n 503,505\r\n     Retained earnings brought forward\r\n  324,053\r\n 102,990\r\n RETAINED EARNINGS\r\n  424,076\r\n 606,495\r\n    \r\n Notes to the annual financial statements of adidas AG for the year \r\nended  ...

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer


def keyword_extraction(tfidf_vector,document_list):
    keywords=[]
    for i in range(0,len(document_list)):
        response2=tfidf_vector.transform([document_list[i]])
        feature_array = np.array(tfidf_vector.get_feature_names())
        tfidf_sorting = np.argsort(response2.toarray()).flatten()[::-1]
        n=12
        top_n = feature_array[tfidf_sorting][:n]
        keywords.append(top_n)
    return keywords


d=open("report4.txt","r",encoding='utf8')
document=d.read()
document_list=document.split("\n\n")
tfidf_vector=TfidfVectorizer(stop_words='english',ngram_range=(1,3))
response=tfidf_vector.fit_transform(document_list)
keywords=keyword_extraction(tfidf_vector,document_list)
keywords=np.asarray(keywords)
print(keywords)
# Out:
# [['report' 'combined management report' 'combined management'
#   'management report' 'report adidas' 'combined'
#   'management report adidas' 'management' 'adidas' 'report adidas group'
#   'section' 'report adidas ag']
#  ['assets' 'income' 'recognized' 'costs' 'adidas' 'cost' 'write'
#   'adidas ag' 'ag' 'transactions' 'useful' 'depreciated']
#  ['tax' 'rate' 'recognized' 'benefit' 'pension' 'obligations'
#   'deferred tax' 'past' 'deferred' 'future' 'balance' 'sheet']
#  ['assets' 'eur' 'thousand' '31' 'receivables' 'dec 31' 'dec' 'capital'
#   'expenses' 'balance' 'liabilities' 'date']
#  ['shares' 'capital' 'subscription' 'rights' 'subscription rights' '000'
#   'new shares' 'conversion' 'board approval' 'authorization' 'approval'
#   'warrant conversion']
#  ['bond' 'notifications' 'convertible bond' 'convertible' 'company' '14'
#   'conversion' 'right' 'terms' 'interests' 'equity interests'
#   'bond terms']
#  ['22 sentence' '22' 'sentence' 'exceeded' 'conjunction 22 sentence'
#   'conjunction 22' 'conjunction' 'company dated'
#   '22 sentence conjunction' 'exceeded 22' 'sentence conjunction 22'
#   'sentence conjunction']
#  ['provisions' 'eur' 'thousand' 'pension' 'members executive board'
#   'members executive' 'accruals' 'provisions accruals' 'members' '2006'
#   '31' 'obligations']
#  ['thousand' 'eur' 'previous year' 'previous' 'year eur'
#   'previous year eur' 'thousand previous' 'thousand previous year'
#   'currency' 'year' 'liabilities' '31']
#  ['thousand' 'eur' 'income' 'thousand previous' 'thousand previous year'
#   'previous year' 'previous year eur' 'year eur' 'previous' 'companies'
#   'taxes' 'tax']
#  ['tax' 'tax assets' 'deferred tax assets' 'deferred tax' 'deferred'
#   'thousand' 'assets' 'eur' 'accounting differences previous'
#   'accounting differences' 'primarily group receivables' 'total eur 41']
#  ['100' 'adidas' '10' 'directly 100' 'directly' 'limited' '10 100'
#   'germany' '285' 'usa' 'reebok' 'britain']
#  ['accounting' 'annual financial' 'annual financial statements'
#   'statements' 'financial statements' 'assurance' 'control evidence'
#   'control evidence supporting' 'accounting related internal'
#   'accounting related' 'audit procedures' 'assurance knowledge business']
#  ['audit' 'framework audit' 'principles used' 'primarily test basis'
#   'primarily test' 'assessing accounting principles'
#   'assessing accounting' 'assessing' 'estimates'
#   'includes assessing accounting' 'includes assessing'
#   'accounting principles']
#  ['management report' 'annual financial statements' 'annual financial'
#   'german' 'fair' 'financial' 'position' 'financial statements'
#   'statements' 'report' 'wirtschaftsprüfer german' 'fair view']
#  ['board' 'executive board' 'executive' 'improve' 'achieve' 'strong'
#   'growth' 'issues' 'group' 'law' 'markets' 'brands']
#  ['business' 'planning' 'risk' 'compliance major'
#   'planning including finance' 'manner deviations' 'planning including'
#   'financial position profitability' 'explained immediately'
#   'group business strategy' 'kept date matters'
#   'explained immediately detailed']
#  ['reports' 'board' 'established plans discussed' 'preparation meetings'
#   'detailed reports' 'detailed reports preparation'
#   'depth supervisory board' 'depth supervisory' 'plans discussed matters'
#   'plans discussed' 'analyse' 'analyse executive']
#  ['depth examination consultation' 'board proposals'
#   'proposals depth examination' 'meetings executive'
#   'meetings executive board' 'consultation periods'
#   'forward suggestions resolving' 'forward suggestions'
#   'consultation periods meetings' 'executive board proposals'
#   'proposals depth' 'informed current']
#  ['took place' 'place' 'took' 'extraordinary' 'regular' 'board'
#   'supervisory' 'supervisory board' 'meetings'
#   'january 2014 extraordinary' 'extraordinary meetings'
#   '2014 extraordinary supervisory']
#  ['members' 'postponed' 'rom regular' 'apart rom' 'matters relating 2013'
#   'apart rom regular' 'prevented attending business'
#   'prevented attending' 'rom regular meeting' 'rom'
#   'postponed supervisory' 'prevented']
#  ['attended' 'meetings' 'committee' 'external auditor'
#   'attendance rate meetings' 'external' 'audit committee general'
#   'exception meeting' 'exception meeting audit' 'general committee fully'
#   'regular meetings year' 'attended external auditor']
#  ['meetings' 'chairman' 'kpmg attended' 'supervisory board chairman'
#   'attended' 'board chairman' 'meetings supervisory'
#   'meetings supervisory board' 'supervisory' 'supervisory board' 'board'
#   'regular']
#  ['development' 'business development' 'situation' 'topics' 'following'
#   'business' 'individual regions presented' 'group segments individual'
#   'regions presented executive' 'following close'
#   'segments individual regions' 'segments individual']
#  ['financial statements' 'statements' 'translation effects development'
#   'ongoing topics discussion' 'ongoing topics'
#   'quarter discussed regularly' 'quarter discussed' 'quarter'
#   'financial statements including' 'kpmg certified 2012'
#   'dealt intensively kpmg' 'br ands march']
#  ['recent' 'negative' 'board' 'earnings' 'executive' 'executive board'
#   'meeting september ex' 'consequences extraordinary meeting'
#   'negative market' 'strategy possible' 'provided information'
#   'negative currency effects']
#  ['approval' 'transactions' 'distribution' 'board' 'supervisory'
#   'supervisory board' 'market' 'approval accordance statutory'
#   'approved budget investment' 'competition' 'competition situation'
#   'competition situation sporting']
#  ['resolved resolutions' 'completion project approved' 'adams golf usa'
#   'ambitious' 'established ad hoc' 'march discussed resolved'
#   'ad hoc related' 'completion' 'completion project'
#   'project approved dissolution' 'committee established ad'
#   'project approved']
#  ['board' 'executive' 'executive board' 'global' 'proposal' 'meeting'
#   'appointment' 'various' 'committee proposal'
#   'general committee proposal' 'following general committee'
#   'following general']
#  ['figures relevant' 'years proposed general'
#   'reassessment necessary financial' 'necessary financial figures'
#   'necessary financial' 'figures relevant determining'
#   'reassessment necessary' 'previous years proposed' 'years proposed'
#   'determining degree' 'reassessment' 'relevant determining degree']
#  ['prior years' 'prior' '2011' 'restatement' '2011 prior'
#   '2011 prior years' 'years' 'financial' 'target achievement executive'
#   'india company led' 'irregularities arisen' 'irregularities']
#  ['governance' 'corporate governance' 'corporate' 'performance' 'bonuses'
#   'compensation' 'resolved' 'board' '2013' 'executive' 'executive board'
#   'february']
#  ['governance' 'corporate' 'corporate governance' 'declaration'
#   'compensation' 'meeting' 'committees' 'code' 'supervisory' 'including'
#   'accordingly' 'report including']
#  ['supervisory' 'supervisory board' 'board' 'resolutions' 'committees'
#   'pass resolutions individual' 'authority pass resolutions'
#   'chairs standing committees' 'delegated' 'delegated supervisory'
#   'delegated supervisory board' 'board topics supervisory']
#  ['committee' 'meetings' 'year review' 'review'
#   'results committee meetings' '2013 way conference' 'relating year'
#   'relating year review' 'supervisory board steering'
#   'meetings subsequent meeting' 'meetings subsequent'
#   'dealing topics relating']
#  ['executive board members' 'board' 'board members' 'resolutions'
#   'members' 'executive' 'executive board' 'general committee'
#   'compensation' 'performance' 'relating' 'general']
#  ['board' 'bonuses' 'executive board' 'executive' 'year review' 'members'
#   'review' 'year' 'performance' 'present' 'committee' 'february']
#  ['audit' 'auditor' 'statements' 'financial statements' 'independence'
#   'audit committee' 'statements consolidated financial'
#   'statements consolidated' 'financial statements consolidated' 'annual'
#   'financial' 'committee']
#  ['information' 'auditor' 'audit' 'does face' 'areas members audit'
#   'areas members' 'areas' 'measures taken' 'measures taken auditor'
#   'ommittee information' 'does face conflicts' 'members audit committee']
#  ['committe members focused' 'control compliance' 'half year report'
#   'ommittee meeting' 'topic risk management' 'risk management internal'
#   'half year' 'half' 'publication ommittee meeting'
#   'publication ommittee' 'ommittee meeting september'
#   'meeting september committe']
#  ['members dealt particular' 'risk factors group' 'dealt particular'
#   'committee members dealt' 'factors' 'factors group'
#   'factors group related' 'group related control' 'group related'
#   'risk factors' 'related control measures' 'particular main risk']
#  ['internal' 'audit' 'internal audit' 'committee members' 'compliance'
#   'members' 'audit plan 2013' 'analysed audit results' 'plan 2013 2014'
#   'plan 2013' 'internal control internal' 'internal audit function']
#  ['systems' 'effectiveness' 'assured effectiveness systems'
#   'course following' 'systems context regular' 'systems context'
#   'following comprehensive discussions' 'following comprehensive'
#   'auditor assured effectiveness' 'regular reporting'
#   'thereof aid written' 'thereof aid']
#  ['hoc' 'ad hoc' 'ad' 'compliance' 'committee' 'statements'
#   'financial statements' 'bond' 'established' 'meeting' 'consolidated'
#   'consolidated financial']
#  ['statements' 'financial statements' 'auditor reports'
#   'earnings auditor' 'board regarding appropriation' 'board regarding'
#   'ag group financial' 'hgb requirements combined' 'hgb requirements'
#   'accordance hgb' 'accordance hgb requirements' 'forward executiv board']
#  ['focus' 'board' 'auditor' 'meetings' 'financial' 'audit' 'statements'
#   'financial statements' 'year topic' 'examined documents depth'
#   'year topic meetings' 'focus priority topics']
#  ['dividend' 'inancial' 'relating accounting'
#   'earnings provides dividend' 'risk management relating'
#   'earnings provides' 'discussed depth executive' 'discussed depth'
#   'accounting process discussed' 'future prospects' 'accounting process'
#   'did report significant']
#  ['thank' 'adidas' 'financial statements' 'statements' 'behalf' 'wish'
#   'wish thank' 'adidas group' 'group' 'board' 'financial' 'approved']]
